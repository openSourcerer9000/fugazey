# %%
from pathlib import Path
import pandas as pd, numpy as np
import geopandas as gpd, xarray as xr
import rioxarray as rxr
g = 'geometry'
pth = Path.cwd()/'data'
pth.mkdir(parents=True,exist_ok=True)
pth
fullxy = xr.open_dataset(pth/'fullxy.nc')
sampdim = 's'
fullxy
# Out:
# <xarray.Dataset>
# Dimensions:  (s: 925, mark: 478, crd: 3, pos: 2)
# Coordinates:
#   * crd      (crd) object 'x' 'y' 'z'
# Dimensions without coordinates: s, mark, pos
# Data variables:
#     head     (s, mark, crd) float64 ...
#     mouse    (s, pos) float64 ...

# %%
lm = fullxy.isel(s=200)['head'].sel(crd=['x','y']).to_pandas()
lm
from pathlib import Path
import pandas as pd, numpy as np
import geopandas as gpd, xarray as xr
import rioxarray as rxr
g = 'geometry'

gdf = gpd.GeoDataFrame(lm,geometry=gpd.points_from_xy(lm.x,lm.y))
gdf.reset_index().to_file(pth/'ptlist.gpkg')

# %%
df = gpd.read_file(pth/'mouthpts.gpkg')
df
# Out:
#      mark         x         y                  geometry
# 0       0 -0.049219  0.146479  POINT (-0.04922 0.14648)
# 1       2 -0.058255  0.101866  POINT (-0.05825 0.10187)
# 2      11 -0.048974  0.154292  POINT (-0.04897 0.15429)
# 3      12 -0.048418  0.162248  POINT (-0.04842 0.16225)
# 4      13 -0.047681  0.167596  POINT (-0.04768 0.16760)
# ..    ...       ...       ...                       ...
# 176   433  0.090176  0.122245   POINT (0.09018 0.12224)
# 177   434  0.056818  0.168700   POINT (0.05682 0.16870)
# 178   435  0.103279  0.137779   POINT (0.10328 0.13778)
# 179   436  0.028838  0.131766   POINT (0.02884 0.13177)
# 180   460 -0.022522  0.091188  POINT (-0.02252 0.09119)
#
# [181 rows x 4 columns]

# %%
df.mark.unique()
# Out:
# array([  0,   2,  11,  12,  13,  14,  15,  16,  17,  18,  32,  37,  38,
#         39,  40,  41,  42,  43,  57,  58,  61,  62,  72,  73,  74,  76,
#         77,  78,  80,  81,  82,  83,  84,  85,  86,  87,  88,  89,  90,
#         91,  92,  95,  96,  97,  98,  99, 106, 132, 135, 136, 138, 140,
#        146, 147, 148, 149, 150, 152, 164, 165, 167, 169, 170, 171, 172,
#        175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187,
#        191, 192, 194, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208,
#        210, 211, 212, 213, 214, 215, 216, 240, 262, 267, 268, 269, 270,
#        271, 272, 273, 287, 288, 291, 292, 302, 303, 304, 306, 307, 308,
#        310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322,
#        324, 325, 326, 327, 335, 361, 364, 365, 367, 369, 375, 376, 377,
#        378, 379, 391, 393, 394, 395, 396, 397, 400, 401, 402, 403, 404,
#        405, 406, 407, 408, 409, 410, 411, 415, 416, 418, 421, 422, 423,
#        424, 426, 427, 428, 430, 431, 432, 433, 434, 435, 436, 460],
#       dtype=int64)
